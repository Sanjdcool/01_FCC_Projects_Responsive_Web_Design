# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjdcool/01_FCC_Projects_Responsive_Web_Design/blob/master/NSE_Data_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from datetime import datetime
from io import BytesIO

class NSE():
    def __init__(self, timeout=10):
        self.base_url = 'https://www.nseindia.com'
        self.session = requests.sessions.Session()
        self.session.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36 Edg/97.0.1072.55",
            "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
            "accept-language": "en-US,en;q=0.9"
        }
        self.timeout = timeout
        self.session.get(self.base_url, timeout=timeout)
        #self.cookies = []
    '''
    def __getCookies(self, renew=False):
        if len(self.cookies) > 0 and renew == False:
            return self.cookies
        r = requests.get(self.base_url, timeout=self.timeout, headers=self.headers)
        self.cookies = dict(r.cookies)
        return self.__getCookies()
    '''
    def getHistoricalData(self, symbol, series, from_date, to_date):
        try:
            url = "/api/historical/cm/equity?symbol={0}&series=[%22{1}%22]&from={2}&to={3}&csv=true".format(symbol.replace('&', '%26'), series, from_date.strftime('%d-%m-%Y'), to_date.strftime('%d-%m-%Y'))
            r = self.session.get(self.base_url + url, timeout=self.timeout)
            df = pd.read_csv(BytesIO(r.content), sep=',', thousands=',')
            df = df.rename(columns={'Date ': 'date', 'series ': 'series', 'OPEN ': 'open', 'HIGH ': 'high', 'LOW ': 'low', 'PREV. CLOSE ': 'prev_close', 'ltp ': 'ltp', 'close ': 'close', '52W H ': 'hi_52_wk', '52W L ': 'lo_52_wk', 'VOLUME ': 'trdqty', 'VALUE ': 'trdval', 'No of trades ': 'trades'})
            df.date = pd.to_datetime(df.date).dt.strftime('%Y-%m-%d')
            return df
        except:
            return None

    def fetch_index_from_nse(self, index_symbol):
        df = []
        res = self.session.get(self.base_url + '/api/equity-stockIndices?index=' + index_symbol, timeout=10)
        if res.status_code == 200:
            res_json = res.json()
            if 'data' in res_json:
                df = pd.json_normalize(res_json['data'])
            else:
                print('Data not returned from NSE')
                print(res_json)
        else:
            print('HTTP Request Failed: ')
            print(res)

        return df

    def save_index_to_csv(self, index_symbol, csv_file_name=None, delimiter=',', index=True, header=True):
        if csv_file_name == None:
            csv_file_name = index_symbol + '.csv'

        df = self.fetch_index_from_nse(index_symbol)
        if len(df) > 0:
            df.to_csv(csv_file_name, sep=delimiter, index=index, header=header)
            return True

        return False


if __name__ == '__main__':
    from datetime import date
    nse = NSE()
    df = nse.getHistoricalData('SBIN', 'EQ', date(2023,1,1), date(2023,5,20))
    print(df)
    print(nse.fetch_index_from_nse('NIFTY MIDCAP 50'))
# Out:
#           date series    open    high     low  prev_close     ltp   close  \
# 0   2023-05-19     EQ  579.00  586.25  569.90      574.20  575.65  575.15
# 1   2023-05-18     EQ  590.30  593.90  571.40      586.30  576.35  574.20
# 2   2023-05-17     EQ  586.00  590.50  579.50      586.30  587.20  586.30
# 3   2023-05-16     EQ  584.00  590.40  582.00      581.90  585.95  586.30
# 4   2023-05-15     EQ  578.75  584.00  574.65      578.15  582.05  581.90
# ..         ...    ...     ...     ...     ...         ...     ...     ...
# 88  2023-01-06     EQ  607.40  607.45  597.00      605.10  601.00  600.65
# 89  2023-01-05     EQ  607.00  611.60  601.95      605.20  605.75  605.10
# 90  2023-01-04     EQ  611.85  614.95  604.00      612.40  605.60  605.20
# 91  2023-01-03     EQ  614.50  616.60  610.00      612.20  612.95  612.40
# 92  2023-01-02     EQ  614.95  619.20  611.20      613.70  612.60  612.20
#
#      vwap   hi_52_wk  lo_52_wk    trdqty        trdval  trades
# 0   576.07    629.55     430.7  42293962  2.436427e+10  351340
# 1   583.00    629.55     430.7  45656620  2.661764e+10  403645
# 2   584.82    629.55     430.7  23739774  1.388340e+10  251054
# 3   586.03    629.55     430.7  22178229  1.299713e+10  233142
# 4   581.35    629.55     430.7  11410243  6.633367e+09  176477
# ..     ...       ...       ...       ...           ...     ...
# 88  601.57    629.55     425.0   7972036  4.795747e+09  154179
# 89  605.84    629.55     425.0   8241475  4.992982e+09  146571
# 90  607.74    629.55     425.0   7011191  4.260969e+09  113548
# 91  613.26    629.55     425.0   6818062  4.181258e+09  122799
# 92  614.42    629.55     425.0   6726084  4.132615e+09  125418
#
# [93 rows x 14 columns]
#     priority           symbol       identifier       open    dayHigh  \
# 0          1  NIFTY MIDCAP 50  NIFTY MIDCAP 50   13541.50   13579.25
# 1          0           SUZLON        SUZLONBEN      39.00      40.40
# 2          0       INDUSTOWER    INDUSTOWEREQN     283.60     292.75
# 3          0         GMRINFRA      GMRINFRAEQN      80.90      82.25
# 4          0           CONCOR        CONCOREQN     869.00     891.70
# 5          0        MAXHEALTH     MAXHEALTHEQN     824.95     827.00
# 6          0       CUMMINSIND    CUMMINSINDEQN    2986.45    3025.00
# 7          0       AUROPHARMA    AUROPHARMAEQN    1070.35    1099.25
# 8          0             BHEL          BHELEQN     253.05     253.70
# 9          0         ASHOKLEY      ASHOKLEYEQN     170.70     172.60
# 10         0       BHARATFORG    BHARATFORGEQN    1114.95    1135.20
# 11         0        HINDPETRO     HINDPETROEQN     475.05     479.35
# 12         0         TATACOMM      TATACOMMEQN    1973.15    2017.70
# 13         0              MRF           MRFEQN  132889.00  134000.00
# 14         0             NMDC          NMDCEQN     200.85     203.65
# 15         0            LUPIN         LUPINEQN    1611.00    1625.00
# 16         0       BALKRISIND    BALKRISINDEQN    2307.40    2333.00
# 17         0           M&MFIN        M&MFINEQN     275.50     280.00
# 18         0         INDHOTEL      INDHOTELEQN     589.50     595.55
# 19         0            PIIND         PIINDEQN    3865.00    3905.90
# 20         0              ACC           ACCEQN    2478.00    2505.00
# 21         0       GODREJPROP    GODREJPROPEQN    2277.10    2315.00
# 22         0            DIXON         DIXONEQN    7486.35    7580.00
# 23         0           AUBANK        AUBANKEQN     563.85     570.45
# 24         0          POLYCAB       POLYCABEQN    5042.00    5116.00
# 25         0             SAIL          SAILEQN     134.80     136.70
# 26         0        GUJGASLTD     GUJGASLTDEQN     545.00     547.00
# 27         0        ABCAPITAL     ABCAPITALEQN     176.90     176.95
# 28         0             LTTS          LTTSEQN    5475.00    5555.00
# 29         0       FEDERALBNK    FEDERALBNKEQN     150.95     151.00
# 30         0              UPL           UPLEQN     458.45     459.70
# 31         0         PETRONET      PETRONETEQN     264.50     268.40
# 32         0          YESBANK       YESBANKEQN      23.20      23.60
# 33         0             IDEA          IDEAEQN      13.30      13.55
# 34         0            L&TFH         L&TFHEQN     159.45     161.10
# 35         0           ASTRAL        ASTRALEQN    2010.00    2012.05
# 36         0             OFSS          OFSSEQN    8802.25    8894.00
# 37         0       BANDHANBNK    BANDHANBNKEQN     181.30     182.00
# 38         0          PAGEIND       PAGEINDEQN   34469.45   34600.00
# 39         0        DALBHARAT     DALBHARATEQN    1956.00    1977.00
# 40         0          MPHASIS       MPHASISEQN    2421.00    2421.00
# 41         0          ESCORTS       ESCORTSEQN    2799.95    2812.35
# 42         0          COFORGE       COFORGEEQN    5569.00    5594.00
# 43         0          HDFCAMC       HDFCAMCEQN    3799.95    3809.75
# 44         0            ALKEM         ALKEMEQN    4935.00    5009.95
# 45         0             MFSL          MFSLEQN    1024.60    1027.40
# 46         0       PERSISTENT    PERSISTENTEQN    4069.00    4096.65
# 47         0         JUBLFOOD      JUBLFOODEQN     455.00     458.40
# 48         0          TIINDIA       TIINDIAEQN    3825.00    3827.95
# 49         0       IDFCFIRSTB    IDFCFIRSTBEQN      76.30      76.30
# 50         0       OBEROIRLTY    OBEROIRLTYEQN    1514.95    1521.20
#
#        dayLow  lastPrice  previousClose   change  pChange  ...  \
# 0    13450.05   13526.50       13460.05    66.45     0.49  ...
# 1       38.60      40.40          38.50     1.90     4.94  ...
# 2      283.25     291.30         283.60     7.70     2.72  ...
# 3       80.25      81.80          79.80     2.00     2.51  ...
# 4      864.60     883.00         866.20    16.80     1.94  ...
# 5      797.30     817.10         802.30    14.80     1.84  ...
# 6     2939.15    3022.95        2968.35    54.60     1.84  ...
# 7     1064.05    1090.00        1070.35    19.65     1.84  ...
# 8      245.60     247.50         243.10     4.40     1.81  ...
# 9      169.55     171.80         169.00     2.80     1.66  ...
# 10    1103.50    1129.50        1111.20    18.30     1.65  ...
# 11     470.10     478.75         471.10     7.65     1.62  ...
# 12    1957.65    2005.00        1973.15    31.85     1.61  ...
# 13  132000.50  133923.00      131809.40  2113.59     1.60  ...
# 14     200.05     202.05         199.00     3.05     1.53  ...
# 15    1593.10    1624.00        1599.95    24.05     1.50  ...
# 16    2275.00    2322.25        2290.85    31.40     1.37  ...
# 17     274.55     277.80         274.45     3.35     1.22  ...
# 18     583.10     593.00         585.85     7.15     1.22  ...
# 19    3801.00    3880.00        3834.90    45.10     1.18  ...
# 20    2453.20    2482.00        2454.10    27.90     1.14  ...
# 21    2248.40    2298.00        2277.00    21.00     0.92  ...
# 22    7431.45    7474.00        7424.20    49.80     0.67  ...
# 23     561.00     565.00         561.50     3.50     0.62  ...
# 24    5004.00    5065.00        5038.20    26.80     0.53  ...
# 25     133.15     134.35         133.65     0.70     0.52  ...
# 26     538.30     544.35         541.75     2.60     0.48  ...
# 27     174.55     176.00         175.55     0.45     0.26  ...
# 28    5427.55    5456.00        5446.30     9.70     0.18  ...
# 29     149.05     150.00         149.80     0.20     0.13  ...
# 30     452.10     456.10         455.50     0.60     0.13  ...
# 31     261.05     264.00         263.75     0.25     0.09  ...
# 32      23.10      23.15          23.15     0.00     0.00  ...
# 33      13.15      13.30          13.30     0.00     0.00  ...
# 34     157.70     159.00         159.00     0.00     0.00  ...
# 35    1982.00    1992.95        1998.10    -5.15    -0.26  ...
# 36    8722.25    8761.00        8802.25   -41.25    -0.47  ...
# 37     179.45     179.90         180.85    -0.95    -0.53  ...
# 38   34100.00   34240.00       34439.95  -199.95    -0.58  ...
# 39    1935.10    1946.00        1957.85   -11.85    -0.61  ...
# 40    2376.95    2392.00        2407.00   -15.00    -0.62  ...
# 41    2754.55    2779.90        2798.70   -18.80    -0.67  ...
# 42    5485.00    5494.00        5549.25   -55.25    -1.00  ...
# 43    3744.15    3756.90        3795.55   -38.65    -1.02  ...
# 44    4820.05    4949.80        5004.20   -54.40    -1.09  ...
# 45     999.00    1004.00        1015.80   -11.80    -1.16  ...
# 46    3947.45    3985.00        8099.65   -64.80    -1.60  ...
# 47     447.35     447.35         454.85    -7.50    -1.65  ...
# 48    3706.00    3730.25        3805.90   -75.65    -1.99  ...
# 49      75.05      75.50          77.80    -2.30    -2.96  ...
# 50    1387.90    1470.00        1514.95   -44.95    -2.97  ...
#
#     meta.isDebtSec  meta.isSuspended  \
# 0              NaN               NaN
# 1            False             False
# 2            False             False
# 3            False             False
# 4            False             False
# 5            False             False
# 6            False             False
# 7            False             False
# 8            False             False
# 9            False             False
# 10           False             False
# 11           False             False
# 12           False             False
# 13           False             False
# 14           False             False
# 15           False             False
# 16           False             False
# 17            True             False
# 18           False             False
# 19           False             False
# 20           False             False
# 21           False             False
# 22           False             False
# 23           False             False
# 24           False             False
# 25           False             False
# 26           False             False
# 27           False             False
# 28           False             False
# 29           False             False
# 30           False             False
# 31           False             False
# 32           False             False
# 33           False             False
# 34           False             False
# 35           False             False
# 36           False             False
# 37           False             False
# 38           False             False
# 39           False             False
# 40           False             False
# 41           False             False
# 42           False             False
# 43           False             False
# 44           False             False
# 45           False             False
# 46           False             False
# 47           False             False
# 48           False             False
# 49           False             False
# 50           False             False
#
#                              meta.tempSuspendedSeries  meta.isETFSec  \
# 0                                                 NaN            NaN
# 1                                                  []          False
# 2                                                  []          False
# 3                                                  []          False
# 4                                                [IL]          False
# 5                                                  []          False
# 6                                                  []          False
# 7                                                  []          False
# 8                                                  []          False
# 9                                                  []          False
# 10                                               [W2]          False
# 11                                               [IL]          False
# 12                                                 []          False
# 13                                                 []          False
# 14                                                 []          False
# 15                                               [IL]          False
# 16                                                 []          False
# 17                                                 []          False
# 18                                       [D1, N4, W1]          False
# 19                                                 []          False
# 20                                               [IL]          False
# 21                                                 []          False
# 22                                                 []          False
# 23                                                 []          False
# 24                                                 []          False
# 25                                                 []          False
# 26                                                 []          False
# 27                                                 []          False
# 28                                                 []          False
# 29                                               [IL]          False
# 30                                       [IL, Q1, Q2]          False
# 31                                               [IL]          False
# 32                                               [IL]          False
# 33                                                 []          False
# 34                                               [BE]          False
# 35                                                 []          False
# 36                                                 []          False
# 37                                                 []          False
# 38                                               [BE]          False
# 39                                                 []          False
# 40                                                 []          False
# 41                                               [D1]          False
# 42                                                 []          False
# 43                                                 []          False
# 44                                                 []          False
# 45                                                 []          False
# 46                                               [IL]          False
# 47                                               [IL]          False
# 48                                                 []          False
# 49  [H1, H6, H7, H8, H9, HA, HB, HC, HD, HE, N1, N...          False
# 50                                                 []          False
#
#     meta.isDelisted     meta.isin  meta.isMunicipalBond  \
# 0               NaN           NaN                   NaN
# 1             False  INE040H01021                 False
# 2             False  INE121J01017                 False
# 3             False  INE776C01039                 False
# 4             False  INE111A01025                 False
# 5             False  INE027H01010                 False
# 6             False  INE298A01020                 False
# 7             False  INE406A01037                 False
# 8             False  INE257A01026                 False
# 9             False  INE208A01029                 False
# 10            False  INE465A13020                 False
# 11            False  INE169701013                 False
# 12            False  INE151A01013                 False
# 13            False  INE883A01011                 False
# 14            False  INE584A01023                 False
# 15            False  INE326A01037                 False
# 16            False  INE787D01026                 False
# 17            False  INE774D08MG3                 False
# 18            False  INE053A13016                 False
# 19            False  INE603J01030                 False
# 20            False  INE012A01025                 False
# 21            False  INE484J01027                 False
# 22            False  INE935N01020                 False
# 23            False  INE949L01017                 False
# 24            False  INE455K01017                 False
# 25            False  INE114A01011                 False
# 26            False  INE844O01030                 False
# 27            False  INE674K01013                 False
# 28            False  INE010V01017                 False
# 29            False  INE171A01029                 False
# 30            False  INE628A03016                 False
# 31            False  INE347G01014                 False
# 32            False  INE528G01035                 False
# 33            False  INE669E01016                 False
# 34            False  INE498L01015                 False
# 35            False  INE006I01046                 False
# 36            False  INE881D01027                 False
# 37            False  INE545U01014                 False
# 38            False  INE761H01022                 False
# 39            False  INE00R701025                 False
# 40            False  INE356A01018                 False
# 41            False  INE042A01014                 False
# 42            False  INE591G01017                 False
# 43            False  INE127D01025                 False
# 44            False  INE540L01014                 False
# 45            False  INE180A01020                 False
# 46            False  INE262H01021                 False
# 47            False  INE797F01020                 False
# 48            False  INE974X01010                 False
# 49            False  INE092T08CP8                 False
# 50            False  INE093I01010                 False
#
#     meta.quotepreopenstatus.equityTime meta.quotepreopenstatus.preOpenTime  \
# 0                                  NaN                                 NaN
# 1                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 2                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 3                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 4                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 5                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 6                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 7                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 8                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 9                 28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 10                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 11                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 12                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 13                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 14                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 15                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 16                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 17                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 18                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 19                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 20                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 21                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 22                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 23                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 24                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 25                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 26                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 27                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 28                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 29                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 30                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 31                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 32                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 33                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 34                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 35                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 36                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 37                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 38                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 39                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 40                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 41                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 42                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 43                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 44                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 45                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 46                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 47                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 48                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 49                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
# 50                28-Mar-2024 16:00:00                28-Mar-2024 09:07:30
#
#    meta.quotepreopenstatus.QuotePreOpenFlag
# 0                                       NaN
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# 5                                     False
# 6                                     False
# 7                                     False
# 8                                     False
# 9                                     False
# 10                                    False
# 11                                    False
# 12                                    False
# 13                                    False
# 14                                    False
# 15                                    False
# 16                                    False
# 17                                    False
# 18                                    False
# 19                                    False
# 20                                    False
# 21                                    False
# 22                                    False
# 23                                    False
# 24                                    False
# 25                                    False
# 26                                    False
# 27                                    False
# 28                                    False
# 29                                    False
# 30                                    False
# 31                                    False
# 32                                    False
# 33                                    False
# 34                                    False
# 35                                    False
# 36                                    False
# 37                                    False
# 38                                    False
# 39                                    False
# 40                                    False
# 41                                    False
# 42                                    False
# 43                                    False
# 44                                    False
# 45                                    False
# 46                                    False
# 47                                    False
# 48                                    False
# 49                                    False
# 50                                    False
#
# [51 rows x 44 columns]
